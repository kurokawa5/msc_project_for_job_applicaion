# %%
conf=[[1522,72,248,44,0,14,2],
 [63,8931,6687,133,0, 81, 14],
 [246,3493,38693,458,6,182, 27],
 [24,103,371,7104,1, 27,4],
 [ 5,3,9,0, 55,0,1],
 [16, 31,133, 16,0,971,4],
 [9, 19, 59,2,0,5,344]]

# %%
conf
# Out:
# [[1522, 72, 248, 44, 0, 14, 2],
#  [63, 8931, 6687, 133, 0, 81, 14],
#  [246, 3493, 38693, 458, 6, 182, 27],
#  [24, 103, 371, 7104, 1, 27, 4],
#  [5, 3, 9, 0, 55, 0, 1],
#  [16, 31, 133, 16, 0, 971, 4],
#  [9, 19, 59, 2, 0, 5, 344]]

# %%
import pandas as pd
import seaborn as sn
import numpy as np
import matplotlib.pyplot as plt

confusion =np.array(conf)
classes = ('anger', 'joy', 'neutral', 'surprise', 'disgust',
        'saddness', 'fear')

# Build confusion matrix
df_cm = pd.DataFrame(confusion/np.sum(confusion) , index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)

# %%
import seaborn as sns
df_cm = pd.DataFrame(confusion/np.sum(confusion) , index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sns.heatmap(df_cm, square=True, cbar=True, annot=True, cmap='Blues')
plt.xlabel("Prediction", fontsize=13)
plt.ylabel("Ground Truth", fontsize=13)
# Out:
# Text(242.16000000000008, 0.5, 'Ground Truth')
